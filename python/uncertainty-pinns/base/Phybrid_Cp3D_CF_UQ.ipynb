# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import sys
sys.path.insert(0,'./')  # add previous directory to path to load constants module
import constants as const

import tensorflow as tf
from tensorflow import keras
#from tensorflow.keras import layers
import keras_tuner as kt
print(tf.__version__)

from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error, r2_score
import statistics
# Out:
# 2.18.0

# %%
#from tensorflow.keras.models import Model
#from tensorflow.keras.layers import Input, Add, Lambda
#import tensorflow.keras.backend as K
from keras import backend as K
#from keras.layers import Input, Lambda
#from keras.layers import Concatenate
Cp_max = 0.5926
V_mean = 6.314169410268349
V_std = 1.9826865496833004
Pres_mean = 548.729493
Pres_std = 30275.282659

Ptotal_model = tf.keras.models.load_model('./Ptotal_Cp3D.h5')
Ptotal_model.summary()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 13
#      10 Pres_mean = 548.729493
#      11 Pres_std = 30275.282659
# ---> 13 Ptotal_model = tf.keras.models.load_model('./Ptotal_Cp3D.h5')
#      14 Ptotal_model.summary()
#
# File ~/code/uncertainty-pinns/.venv/lib/python3.10/site-packages/keras/src/saving/saving_api.py:196, in load_model(filepath, custom_objects, compile, safe_mode)
#     189     return saving_lib.load_model(
#     190         filepath,
#     191         custom_objects=custom_objects,
#     192         compile=compile,
#     193         safe_mode=safe_mode,
#     194     )
#     195 if str(filepath).endswith((".h5", ".hdf5")):
# --> 196     return legacy_h5_format.load_model_from_hdf5(
#     197         filepath, custom_objects=custom_objects, compile=compile
#     198     )
#     199 elif str(filepath).endswith(".keras"):
#     200     raise ValueError(
#     201         f"File not found: filepath={filepath}. "
#     202         "Please ensure the file is an accessible `.keras` "
#     203         "zip file."
#     204     )
#
# File ~/code/uncertainty-pinns/.venv/lib/python3.10/site-packages/keras/src/legacy/saving/legacy_h5_format.py:133, in load_model_from_hdf5(filepath, custom_objects, compile)
#     130 model_config = json_utils.decode(model_config)
#     132 with saving_options.keras_option_scope(use_legacy_config=True):
# --> 133     model = saving_utils.model_from_config(
#     134         model_config, custom_objects=custom_objects
#     135     )
#     137     # set weights
#     138     load_weights_from_hdf5_group(f["model_weights"], model)
#
# File ~/code/uncertainty-pinns/.venv/lib/python3.10/site-packages/keras/src/legacy/saving/saving_utils.py:85, in model_from_config(config, custom_objects)
#      81 # TODO(nkovela): Swap find and replace args during Keras 3.0 release
#      82 # Replace keras refs with keras
#      83 config = _find_replace_nested_dict(config, "keras.", "keras.")
# ---> 85 return serialization.deserialize_keras_object(
#      86     config,
#      87     module_objects=MODULE_OBJECTS.ALL_OBJECTS,
#      88     custom_objects=custom_objects,
#      89     printable_module_name="layer",
#      90 )
#
# File ~/code/uncertainty-pinns/.venv/lib/python3.10/site-packages/keras/src/legacy/saving/serialization.py:495, in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     490 cls_config = _find_replace_nested_dict(
#     491     cls_config, "keras.", "keras."
#     492 )
#     494 if "custom_objects" in arg_spec.args:
# --> 495     deserialized_obj = cls.from_config(
#     496         cls_config,
#     497         custom_objects={
#     498             **object_registration.GLOBAL_CUSTOM_OBJECTS,
#     499             **custom_objects,
#     500         },
#     501     )
#     502 else:
#     503     with object_registration.CustomObjectScope(custom_objects):
#
# File ~/code/uncertainty-pinns/.venv/lib/python3.10/site-packages/keras/src/models/model.py:526, in Model.from_config(cls, config, custom_objects)
#     521 if is_functional_config and revivable_as_functional:
#     522     # Revive Functional model
#     523     # (but not Functional subclasses with a custom __init__)
#     524     from keras.src.models.functional import functional_from_config
# --> 526     return functional_from_config(
#     527         cls, config, custom_objects=custom_objects
#     528     )
#     530 # Either the model has a custom __init__, or the config
#     531 # does not contain all the information necessary to
#     532 # revive a Functional model. This happens when the user creates
#    (...)
#     535 # In this case, we fall back to provide all config into the
#     536 # constructor of the class.
#     537 try:
#
# File ~/code/uncertainty-pinns/.venv/lib/python3.10/site-packages/keras/src/models/functional.py:499, in functional_from_config(cls, config, custom_objects)
#     497 # First, we create all layers and enqueue nodes to be processed
#     498 for layer_data in config["layers"]:
# --> 499     process_layer(layer_data)
#     501 # Then we process nodes in order of layer depth.
#     502 # Nodes that cannot yet be processed (if the inbound node
#     503 # does not yet exist) are re-enqueued, and the process
#     504 # is repeated until all nodes are processed.
#     505 while unprocessed_nodes:
#
# File ~/code/uncertainty-pinns/.venv/lib/python3.10/site-packages/keras/src/models/functional.py:479, in functional_from_config.<locals>.process_layer(layer_data)
#     475 # Instantiate layer.
#     476 if "module" not in layer_data:
#     477     # Legacy format deserialization (no "module" key)
#     478     # used for H5 and SavedModel formats
# --> 479     layer = saving_utils.model_from_config(
#     480         layer_data, custom_objects=custom_objects
#     481     )
#     482 else:
#     483     layer = serialization_lib.deserialize_keras_object(
#     484         layer_data, custom_objects=custom_objects
#     485     )
#
# File ~/code/uncertainty-pinns/.venv/lib/python3.10/site-packages/keras/src/legacy/saving/saving_utils.py:85, in model_from_config(config, custom_objects)
#      81 # TODO(nkovela): Swap find and replace args during Keras 3.0 release
#      82 # Replace keras refs with keras
#      83 config = _find_replace_nested_dict(config, "keras.", "keras.")
# ---> 85 return serialization.deserialize_keras_object(
#      86     config,
#      87     module_objects=MODULE_OBJECTS.ALL_OBJECTS,
#      88     custom_objects=custom_objects,
#      89     printable_module_name="layer",
#      90 )
#
# File ~/code/uncertainty-pinns/.venv/lib/python3.10/site-packages/keras/src/legacy/saving/serialization.py:495, in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     490 cls_config = _find_replace_nested_dict(
#     491     cls_config, "keras.", "keras."
#     492 )
#     494 if "custom_objects" in arg_spec.args:
# --> 495     deserialized_obj = cls.from_config(
#     496         cls_config,
#     497         custom_objects={
#     498             **object_registration.GLOBAL_CUSTOM_OBJECTS,
#     499             **custom_objects,
#     500         },
#     501     )
#     502 else:
#     503     with object_registration.CustomObjectScope(custom_objects):
#
# File ~/code/uncertainty-pinns/.venv/lib/python3.10/site-packages/keras/src/models/model.py:526, in Model.from_config(cls, config, custom_objects)
#     521 if is_functional_config and revivable_as_functional:
#     522     # Revive Functional model
#     523     # (but not Functional subclasses with a custom __init__)
#     524     from keras.src.models.functional import functional_from_config
# --> 526     return functional_from_config(
#     527         cls, config, custom_objects=custom_objects
#     528     )
#     530 # Either the model has a custom __init__, or the config
#     531 # does not contain all the information necessary to
#     532 # revive a Functional model. This happens when the user creates
#    (...)
#     535 # In this case, we fall back to provide all config into the
#     536 # constructor of the class.
#     537 try:
#
# File ~/code/uncertainty-pinns/.venv/lib/python3.10/site-packages/keras/src/models/functional.py:518, in functional_from_config(cls, config, custom_objects)
#     516 node_data = node_data_list[node_index]
#     517 try:
# --> 518     process_node(layer, node_data)
#     520 # If the node does not have all inbound layers
#     521 # available, stop processing and continue later
#     522 except IndexError:
#
# File ~/code/uncertainty-pinns/.venv/lib/python3.10/site-packages/keras/src/models/functional.py:462, in functional_from_config.<locals>.process_node(layer, node_data)
#     455 def process_node(layer, node_data):
#     456     """Reconstruct node by linking to inbound layers
#     457
#     458     Args:
#     459         layer: Layer to process
#     460         node_data: List of layer configs
#     461     """
# --> 462     args, kwargs = deserialize_node(node_data, created_layers)
#     463     # Call layer on its inputs, thus creating the node
#     464     # and building the layer if needed.
#     465     layer(*args, **kwargs)
#
# File ~/code/uncertainty-pinns/.venv/lib/python3.10/site-packages/keras/src/models/functional.py:661, in deserialize_node(node_data, created_layers)
#     657 inbound_layer = created_layers[inbound_layer_name]
#     659 # Raise an error if the corresponding layer node
#     660 # has not yet been created
# --> 661 if len(inbound_layer._inbound_nodes) <= inbound_node_index:
#     662     raise IndexError(
#     663         "Layer node index out of bounds.\n"
#     664         f"inbound_layer = {inbound_layer}\n"
#    (...)
#     667         f"inbound_node_index = {inbound_node_index}"
#     668     )
#     669 inbound_node = inbound_layer._inbound_nodes[inbound_node_index]
#
# KeyboardInterrupt:

# %%
features_dataset = pd.read_csv('./Dataset_test_features_UQ.csv')
P_dataset = pd.read_csv('./Dataset_test_P_UQ.csv')

# Remove the first column (unnamed) if it exists
features_dataset = features_dataset.drop(columns=['Unnamed: 0'], errors='ignore')
P_dataset = P_dataset.drop(columns=['Unnamed: 0'], errors='ignore')
print(P_dataset.columns)
print(features_dataset.columns)
print(P_dataset.shape)
print(features_dataset.shape)
# Out:
# Index(['P'], dtype='object')
# Index(['V', 'theta', 'W', 'theta.1', 'nacelle_temperature', 'V.1',
#        'Vane_angle', 'Out_temperature', 'W.1', 'Rotor_temperature',
#        'Wind_angle_c'],
#       dtype='object')
# (120530, 1)
# (120530, 11)

# %%
# Plot distributions of P_res in kW
Ptotal_data = Ptotal_model.predict(features_dataset)
plt.figure(figsize=(8,6))
plt.hist(Ptotal_data/1000, range=[0, 2000], bins=100,label='Predicted Power')
plt.xlabel('P_total (kW)',fontsize=15)
plt.ylabel('Data Distribution',fontsize=15)
#plt.title('Predicted Power',fontsize=20)
#plt.show()

Ptotal_data = P_dataset
#plt.figure(figsize=(4,4))
plt.hist(Ptotal_data/1000, range=[0, 2000], bins=100,label='True Power',alpha=0.7)
#plt.xlabel('P_total (kW)',fontsize=15)
#plt.ylabel('Data Distribution',fontsize=15)
#plt.title('True Power',fontsize=20)
plt.legend()
plt.show()
# Out:
# 3767/3767 [==============================] - 2s 436us/step

# %%
# Split test_dataset into calibration and validation sets for conformal prediction
from sklearn.model_selection import train_test_split
X_calib, X_val, y_calib, y_val = train_test_split(features_dataset, P_dataset, test_size=0.5, random_state=42)
print(X_calib.shape)
print(y_calib.shape)
print(X_val.shape)
print(y_val.shape)
# Out:
# (60265, 11)
# (60265, 1)
# (60265, 11)
# (60265, 1)
