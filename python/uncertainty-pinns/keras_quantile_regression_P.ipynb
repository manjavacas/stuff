# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import tensorflow as tf

from tensorflow.keras.models import load_model
from tensorflow.keras.optimizers import Adam

from sklearn.base import BaseEstimator, RegressorMixin
from sklearn.model_selection import train_test_split

from mapie.regression import MapieQuantileRegressor

import sys
sys.path.insert(0,'./') # neccesary to load constants module
import constants as const

SEED = 42

# %% [markdown]
# # **Load pre-trained power model**

# %%
# import sys
# sys.path.insert(0,'./')  # add current to path to load constants module
# import constants as const

# import tensorflow as tf
# from tensorflow import keras
# from tensorflow.keras.models import load_model
from keras import backend as K

Cp_max = 0.5926
V_mean = 6.314169410268349
V_std = 1.9826865496833004
Pres_mean = 548.729493
Pres_std = 30275.282659

# model_tf = load_model('./Ptotal_Cp3D.h5')
# model_tf.save('modelP.keras')

# %%
model_tf = load_model(filepath='modelP.keras')
model_tf.summary()
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Model: "model_5"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_6 (InputLayer)           [(None, 11)]         0           []
#
#  lambda_5 (Lambda)              (None, 3)            0           ['input_6[0][0]']
#
#  lambda_6 (Lambda)              (None, 8)            0           ['input_6[0][0]']
#
#  model (Functional)             (None, 1)            17153       ['lambda_5[0][0]']
#
#  model_3 (Functional)           (None, 1)            17793       ['lambda_6[0][0]']
#
#  tf.__operators__.add_3 (TFOpLa  (None, 1)           0           ['model[0][0]',
#  mbda)                                                            'model_3[0][0]']
#
# ==================================================================================================
# Total params: 34,946
# Trainable params: 34,946
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# #### Test to visualize the model

# %%
""" features_dataset = pd.read_csv('./Dataset_test_features_UQ.csv')
P_dataset = pd.read_csv('./Dataset_test_P_UQ.csv')

# Remove the first column (unnamed) if it exists
features_dataset = features_dataset.drop(columns=['Unnamed: 0'], errors='ignore')
P_dataset = P_dataset.drop(columns=['Unnamed: 0'], errors='ignore')
print(P_dataset.columns)
print(features_dataset.columns)
print(P_dataset.shape)
print(features_dataset.shape)

# Plot distributions of P_res in kW
Ptotal_data = model_tf.predict(features_dataset)
plt.figure(figsize=(8,6))
plt.hist(Ptotal_data/1000, range=[0, 2000], bins=100,label='Predicted Power')
plt.xlabel('P_total (kW)',fontsize=15)
plt.ylabel('Data Distribution',fontsize=15)
#plt.title('Predicted Power',fontsize=20)
#plt.show()

Ptotal_data = P_dataset
#plt.figure(figsize=(4,4))
plt.hist(Ptotal_data/1000, range=[0, 2000], bins=100,label='True Power',alpha=0.7)
#plt.xlabel('P_total (kW)',fontsize=15)
#plt.ylabel('Data Distribution',fontsize=15)
#plt.title('True Power',fontsize=20)
plt.legend()
plt.show() """
# Out:
# " features_dataset = pd.read_csv('./Dataset_test_features_UQ.csv')\nP_dataset = pd.read_csv('./Dataset_test_P_UQ.csv')\n\n# Remove the first column (unnamed) if it exists\nfeatures_dataset = features_dataset.drop(columns=['Unnamed: 0'], errors='ignore')\nP_dataset = P_dataset.drop(columns=['Unnamed: 0'], errors='ignore')\nprint(P_dataset.columns)\nprint(features_dataset.columns)\nprint(P_dataset.shape)\nprint(features_dataset.shape)\n\n# Plot distributions of P_res in kW\nPtotal_data = model_tf.predict(features_dataset)\nplt.figure(figsize=(8,6))\nplt.hist(Ptotal_data/1000, range=[0, 2000], bins=100,label='Predicted Power')\nplt.xlabel('P_total (kW)',fontsize=15)\nplt.ylabel('Data Distribution',fontsize=15)\n#plt.title('Predicted Power',fontsize=20)\n#plt.show()\n\nPtotal_data = P_dataset\n#plt.figure(figsize=(4,4))\nplt.hist(Ptotal_data/1000, range=[0, 2000], bins=100,label='True Power',alpha=0.7)\n#plt.xlabel('P_total (kW)',fontsize=15)\n#plt.ylabel('Data Distribution',fontsize=15)\n#plt.title('True Power',fontsize=20)\nplt.legend()\nplt.show() "

# %% [markdown]
# # **Prepare data**
#
# Load, preprocess and split dat into test and calibration sets

# %%
features_dataset = pd.read_csv('./Dataset_test_features_UQ.csv')
P_dataset = pd.read_csv('./Dataset_test_P_UQ.csv')

# Remove the first column (unnamed) if it exists
features_dataset = features_dataset.drop(columns=['Unnamed: 0'], errors='ignore')
P_dataset = P_dataset.drop(columns=['Unnamed: 0'], errors='ignore')

# Standarize Y data. X data is already standarized
P_mean = 444860.879260
P_std = 446349.165241
P_dataset = (P_dataset - P_mean) / P_std

sample_size = 10000

# Take a random sample
features_sample = features_dataset.sample(n=sample_size, random_state=42)
P_sample = P_dataset.loc[features_sample.index]  # Use the same indices for P_dataset

print(P_dataset.columns)
print(features_dataset.columns)
print(P_dataset.shape)
print(features_dataset.shape)

print(P_sample.shape)
print(features_sample.shape)
# Out:
# Index(['P'], dtype='object')
# Index(['V', 'theta', 'W', 'theta.1', 'nacelle_temperature', 'V.1',
#        'Vane_angle', 'Out_temperature', 'W.1', 'Rotor_temperature',
#        'Wind_angle_c'],
#       dtype='object')
# (120530, 1)
# (120530, 11)
# (10000, 1)
# (10000, 11)

# %%
# Convert pd dataframe to numpy 
features_sample = features_sample.to_numpy()
P_sample = P_sample.to_numpy()

# Split data
X_cal, X_test, y_cal, y_test = train_test_split(features_sample, P_sample, test_size=0.5, random_state=42)
""" features_dataset = features_dataset.to_numpy()
P_dataset = P_dataset.to_numpy()
X_cal, X_test, y_cal, y_test = train_test_split(features_dataset, P_dataset, test_size=0.5, random_state=42) """
print(X_cal.shape)
print(y_cal.shape)
print(X_test.shape)
print(y_test.shape)

y_cal = y_cal.flatten()
y_test = y_test.flatten()
# Out:
# (5000, 11)
# (5000, 1)
# (5000, 11)
# (5000, 1)

# %% [markdown]
# # **Train and save models**
#
# Create, train and save Keras models:
#
# * `model_up` with tau = (1-alpha)/2
# * `model_low` with tau = alpha/2
# * `model` with tau = 0.5

# %%
alpha = .1

def pinball_loss(y_true, y_pred, tau=0.5):
    error = y_true - y_pred
    return tf.reduce_mean(tf.maximum(tau * error, (tau - 1) * error))

def plot_loss(history):
    
    # Plot the loss
    plt.plot(history.history['loss'], label='loss')
    plt.plot(history.history['val_loss'], label='val_loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss [P_res]')
    plt.legend()
    plt.grid(True)

    val_loss_per_epoch = history.history['val_loss']
    train_loss_per_epoch = history.history['loss']
    best_epoch = val_loss_per_epoch.index(min(val_loss_per_epoch)) + 1
    print('Best epoch: %d' % (best_epoch,))

# %%
model_up = load_model('modelP.keras')

loss_fn = lambda y_true, y_pred: pinball_loss(y_true, y_pred, tau=(1-alpha)/2)

model_up.compile(optimizer='adam', loss=loss_fn)

history_up = model_up.fit(X_cal, y_cal, epochs=100, batch_size=32, validation_split=.2)

model_up.save('modelP_up.keras')

plot_loss(history_up)
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Epoch 1/100
# 125/125 [==============================] - 1s 2ms/step - loss: 71570.9141 - val_loss: 9207.4521
# Epoch 2/100
# 125/125 [==============================] - 0s 972us/step - loss: 6600.6133 - val_loss: 3953.5957
# Epoch 3/100
# 125/125 [==============================] - 0s 923us/step - loss: 3670.4934 - val_loss: 2775.5337
# Epoch 4/100
# 125/125 [==============================] - 0s 880us/step - loss: 2604.7954 - val_loss: 2200.9194
# Epoch 5/100
# 125/125 [==============================] - 0s 895us/step - loss: 2014.0299 - val_loss: 1819.3529
# Epoch 6/100
# 125/125 [==============================] - 0s 898us/step - loss: 1620.3206 - val_loss: 1668.8562
# Epoch 7/100
# 125/125 [==============================] - 0s 891us/step - loss: 1345.0680 - val_loss: 1320.2329
# Epoch 8/100
# 125/125 [==============================] - 0s 892us/step - loss: 1105.6447 - val_loss: 1121.5895
# Epoch 9/100
# 125/125 [==============================] - 0s 905us/step - loss: 952.1034 - val_loss: 966.7887
# Epoch 10/100
# 125/125 [==============================] - 0s 918us/step - loss: 813.8608 - val_loss: 911.7809
# Epoch 11/100
# 125/125 [==============================] - 0s 917us/step - loss: 703.9988 - val_loss: 810.7118
# Epoch 12/100
# 125/125 [==============================] - 0s 1ms/step - loss: 621.5684 - val_loss: 715.3872
# Epoch 13/100
# 125/125 [==============================] - 0s 942us/step - loss: 554.2796 - val_loss: 671.4446
# Epoch 14/100
# 125/125 [==============================] - 0s 951us/step - loss: 470.8116 - val_loss: 594.6807
# Epoch 15/100
# 125/125 [==============================] - 0s 949us/step - loss: 414.0222 - val_loss: 548.2432
# Epoch 16/100
# 125/125 [==============================] - 0s 900us/step - loss: 362.8998 - val_loss: 474.7229
# Epoch 17/100
# 125/125 [==============================] - 0s 879us/step - loss: 333.8181 - val_loss: 461.9850
# Epoch 18/100
# 125/125 [==============================] - 0s 902us/step - loss: 293.6320 - val_loss: 416.2466
# Epoch 19/100
# 125/125 [==============================] - 0s 910us/step - loss: 257.7975 - val_loss: 375.7648
# Epoch 20/100
# 125/125 [==============================] - 0s 870us/step - loss: 237.6241 - val_loss: 385.2254
# Epoch 21/100
# 125/125 [==============================] - 0s 927us/step - loss: 219.0493 - val_loss: 329.7612
# Epoch 22/100
# 125/125 [==============================] - 0s 1ms/step - loss: 200.7987 - val_loss: 308.4353
# Epoch 23/100
# 125/125 [==============================] - 0s 984us/step - loss: 182.5700 - val_loss: 274.0152
# Epoch 24/100
# 125/125 [==============================] - 0s 1ms/step - loss: 164.2071 - val_loss: 264.2189
# Epoch 25/100
# 125/125 [==============================] - 0s 911us/step - loss: 155.1382 - val_loss: 240.1643
# Epoch 26/100
# 125/125 [==============================] - 0s 939us/step - loss: 148.9566 - val_loss: 226.9203
# Epoch 27/100
# 125/125 [==============================] - 0s 957us/step - loss: 131.5813 - val_loss: 220.7193
# Epoch 28/100
# 125/125 [==============================] - 0s 937us/step - loss: 122.8815 - val_loss: 201.8297
# Epoch 29/100
# 125/125 [==============================] - 0s 960us/step - loss: 118.1625 - val_loss: 180.9176
# Epoch 30/100
# 125/125 [==============================] - 0s 911us/step - loss: 109.5880 - val_loss: 173.2736
# Epoch 31/100
# 125/125 [==============================] - 0s 935us/step - loss: 102.6677 - val_loss: 174.9797
# Epoch 32/100
# 125/125 [==============================] - 0s 910us/step - loss: 98.4287 - val_loss: 161.8597
# Epoch 33/100
# 125/125 [==============================] - 0s 905us/step - loss: 92.6732 - val_loss: 156.3406
# Epoch 34/100
# 125/125 [==============================] - 0s 923us/step - loss: 88.3229 - val_loss: 130.5361
# Epoch 35/100
# 125/125 [==============================] - 0s 919us/step - loss: 82.8020 - val_loss: 125.6362
# Epoch 36/100
# 125/125 [==============================] - 0s 920us/step - loss: 76.4236 - val_loss: 124.6876
# Epoch 37/100
# 125/125 [==============================] - 0s 920us/step - loss: 65.4037 - val_loss: 103.4170
# Epoch 38/100
# 125/125 [==============================] - 0s 915us/step - loss: 56.1581 - val_loss: 92.7416
# Epoch 39/100
# 125/125 [==============================] - 0s 935us/step - loss: 55.1878 - val_loss: 84.3084
# Epoch 40/100
# 125/125 [==============================] - 0s 1ms/step - loss: 45.5002 - val_loss: 74.1699
# Epoch 41/100
# 125/125 [==============================] - 0s 935us/step - loss: 40.5778 - val_loss: 71.4772
# Epoch 42/100
# 125/125 [==============================] - 0s 986us/step - loss: 38.6252 - val_loss: 63.6271
# Epoch 43/100
# 125/125 [==============================] - 0s 1ms/step - loss: 30.2113 - val_loss: 61.2287
# Epoch 44/100
# 125/125 [==============================] - 0s 931us/step - loss: 29.6200 - val_loss: 46.7401
# Epoch 45/100
# 125/125 [==============================] - 0s 1ms/step - loss: 25.2226 - val_loss: 47.3819
# Epoch 46/100
# 125/125 [==============================] - 0s 1ms/step - loss: 21.6531 - val_loss: 50.8965
# Epoch 47/100
# 125/125 [==============================] - 0s 924us/step - loss: 20.1290 - val_loss: 35.0168
# Epoch 48/100
# 125/125 [==============================] - 0s 961us/step - loss: 16.7370 - val_loss: 22.7586
# Epoch 49/100
# 125/125 [==============================] - 0s 963us/step - loss: 16.7183 - val_loss: 30.4247
# Epoch 50/100
# 125/125 [==============================] - 0s 905us/step - loss: 12.8243 - val_loss: 24.8049
# Epoch 51/100
# 125/125 [==============================] - 0s 927us/step - loss: 13.1480 - val_loss: 25.9511
# Epoch 52/100
# 125/125 [==============================] - 0s 938us/step - loss: 9.6915 - val_loss: 19.9945
# Epoch 53/100
# 125/125 [==============================] - 0s 938us/step - loss: 10.7319 - val_loss: 23.5741
# Epoch 54/100
# 125/125 [==============================] - 0s 919us/step - loss: 9.3837 - val_loss: 21.3857
# Epoch 55/100
# 125/125 [==============================] - 0s 982us/step - loss: 8.3927 - val_loss: 18.7480
# Epoch 56/100
# 125/125 [==============================] - 0s 924us/step - loss: 5.6803 - val_loss: 16.3097
# Epoch 57/100
# 125/125 [==============================] - 0s 931us/step - loss: 4.1426 - val_loss: 16.9023
# Epoch 58/100
# 125/125 [==============================] - 0s 999us/step - loss: 5.3111 - val_loss: 18.0337
# Epoch 59/100
# 125/125 [==============================] - 0s 970us/step - loss: 4.5381 - val_loss: 15.0067
# Epoch 60/100
# 125/125 [==============================] - 0s 1ms/step - loss: 3.3021 - val_loss: 14.3597
# Epoch 61/100
# 125/125 [==============================] - 0s 1ms/step - loss: 4.3411 - val_loss: 13.0565
# Epoch 62/100
# 125/125 [==============================] - 0s 1ms/step - loss: 3.8321 - val_loss: 13.8109
# Epoch 63/100
# 125/125 [==============================] - 0s 995us/step - loss: 3.9936 - val_loss: 12.6467
# Epoch 64/100
# 125/125 [==============================] - 0s 1ms/step - loss: 3.4234 - val_loss: 13.9326
# Epoch 65/100
# 125/125 [==============================] - 0s 956us/step - loss: 3.2946 - val_loss: 11.9320
# Epoch 66/100
# 125/125 [==============================] - 0s 947us/step - loss: 3.0114 - val_loss: 12.7743
# Epoch 67/100
# 125/125 [==============================] - 0s 957us/step - loss: 2.9863 - val_loss: 14.5046
# Epoch 68/100
# 125/125 [==============================] - 0s 985us/step - loss: 3.1745 - val_loss: 12.4326
# Epoch 69/100
# 125/125 [==============================] - 0s 988us/step - loss: 2.3113 - val_loss: 13.5326
# Epoch 70/100
# 125/125 [==============================] - 0s 950us/step - loss: 2.0916 - val_loss: 11.6921
# Epoch 71/100
# 125/125 [==============================] - 0s 950us/step - loss: 2.2729 - val_loss: 14.1845
# Epoch 72/100
# 125/125 [==============================] - 0s 991us/step - loss: 2.7910 - val_loss: 12.2519
# Epoch 73/100
# 125/125 [==============================] - 0s 955us/step - loss: 1.8712 - val_loss: 10.6265
# Epoch 74/100
# 125/125 [==============================] - 0s 960us/step - loss: 2.1636 - val_loss: 10.1015
# Epoch 75/100
# 125/125 [==============================] - 0s 958us/step - loss: 1.9423 - val_loss: 12.6376
# Epoch 76/100
# 125/125 [==============================] - 0s 958us/step - loss: 2.2937 - val_loss: 9.8596
# Epoch 77/100
# 125/125 [==============================] - 0s 965us/step - loss: 1.8873 - val_loss: 11.4378
# Epoch 78/100
# 125/125 [==============================] - 0s 946us/step - loss: 2.0245 - val_loss: 10.6177
# Epoch 79/100
# 125/125 [==============================] - 0s 951us/step - loss: 1.8147 - val_loss: 11.0512
# Epoch 80/100
# 125/125 [==============================] - 0s 956us/step - loss: 1.4624 - val_loss: 10.4219
# Epoch 81/100
# 125/125 [==============================] - 0s 950us/step - loss: 1.5350 - val_loss: 12.4588
# Epoch 82/100
# 125/125 [==============================] - 0s 966us/step - loss: 1.4578 - val_loss: 11.0914
# Epoch 83/100
# 125/125 [==============================] - 0s 943us/step - loss: 1.1862 - val_loss: 11.0860
# Epoch 84/100
# 125/125 [==============================] - 0s 934us/step - loss: 1.3367 - val_loss: 9.9479
# Epoch 85/100
# 125/125 [==============================] - 0s 944us/step - loss: 1.8200 - val_loss: 10.3173
# Epoch 86/100
# 125/125 [==============================] - 0s 924us/step - loss: 1.2403 - val_loss: 10.4717
# Epoch 87/100
# 125/125 [==============================] - 0s 922us/step - loss: 1.5612 - val_loss: 10.6950
# Epoch 88/100
# 125/125 [==============================] - 0s 973us/step - loss: 2.2389 - val_loss: 11.4582
# Epoch 89/100
# 125/125 [==============================] - 0s 937us/step - loss: 1.2427 - val_loss: 10.9876
# Epoch 90/100
# 125/125 [==============================] - 0s 952us/step - loss: 1.5381 - val_loss: 13.7611
# Epoch 91/100
# 125/125 [==============================] - 0s 914us/step - loss: 1.9119 - val_loss: 12.4951
# Epoch 92/100
# 125/125 [==============================] - 0s 928us/step - loss: 1.7883 - val_loss: 11.3357
# Epoch 93/100
# 125/125 [==============================] - 0s 914us/step - loss: 1.6008 - val_loss: 11.1374
# Epoch 94/100
# 125/125 [==============================] - 0s 943us/step - loss: 1.3323 - val_loss: 13.7496
# Epoch 95/100
# 125/125 [==============================] - 0s 948us/step - loss: 3.0418 - val_loss: 11.0719
# Epoch 96/100
# 125/125 [==============================] - 0s 965us/step - loss: 1.2475 - val_loss: 12.5698
# Epoch 97/100
# 125/125 [==============================] - 0s 949us/step - loss: 1.1540 - val_loss: 13.2147
# Epoch 98/100
# 125/125 [==============================] - 0s 949us/step - loss: 1.6971 - val_loss: 10.5009
# Epoch 99/100
# 125/125 [==============================] - 0s 965us/step - loss: 1.0180 - val_loss: 13.1051
# Epoch 100/100
# 125/125 [==============================] - 0s 939us/step - loss: 2.4489 - val_loss: 9.9602
# Best epoch: 76

# %%
model_low = load_model('modelP.keras')

loss_fn = lambda y_true, y_pred: pinball_loss(y_true, y_pred, tau=alpha/2)

model_low.compile(optimizer='adam', loss=loss_fn)

history_low = model_low.fit(X_cal, y_cal, epochs=100, batch_size=32, validation_split=.2)

model_up.save('modelP_low.keras')

plot_loss(history_low)
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# Epoch 1/100
# 125/125 [==============================] - 1s 2ms/step - loss: 107684.5469 - val_loss: 6173.9658
# Epoch 2/100
# 125/125 [==============================] - 0s 928us/step - loss: 5183.1270 - val_loss: 3202.5740
# Epoch 3/100
# 125/125 [==============================] - 0s 960us/step - loss: 2753.3916 - val_loss: 1751.8422
# Epoch 4/100
# 125/125 [==============================] - 0s 911us/step - loss: 1638.7274 - val_loss: 1347.9487
# Epoch 5/100
# 125/125 [==============================] - 0s 896us/step - loss: 1230.2393 - val_loss: 1068.7151
# Epoch 6/100
# 125/125 [==============================] - 0s 913us/step - loss: 1017.8203 - val_loss: 907.5098
# Epoch 7/100
# 125/125 [==============================] - 0s 892us/step - loss: 841.9343 - val_loss: 814.9393
# Epoch 8/100
# 125/125 [==============================] - 0s 927us/step - loss: 736.0111 - val_loss: 765.2629
# Epoch 9/100
# 125/125 [==============================] - 0s 939us/step - loss: 631.9151 - val_loss: 690.0167
# Epoch 10/100
# 125/125 [==============================] - 0s 910us/step - loss: 561.1479 - val_loss: 587.8564
# Epoch 11/100
# 125/125 [==============================] - 0s 934us/step - loss: 513.4487 - val_loss: 548.4252
# Epoch 12/100
# 125/125 [==============================] - 0s 901us/step - loss: 451.6045 - val_loss: 510.7970
# Epoch 13/100
# 125/125 [==============================] - 0s 935us/step - loss: 414.7845 - val_loss: 473.5522
# Epoch 14/100
# 125/125 [==============================] - 0s 935us/step - loss: 383.5698 - val_loss: 497.6075
# Epoch 15/100
# 125/125 [==============================] - 0s 943us/step - loss: 360.4646 - val_loss: 449.3375
# Epoch 16/100
# 125/125 [==============================] - 0s 931us/step - loss: 341.6000 - val_loss: 397.0435
# Epoch 17/100
# 125/125 [==============================] - 0s 943us/step - loss: 317.8338 - val_loss: 410.8462
# Epoch 18/100
# 125/125 [==============================] - 0s 919us/step - loss: 292.8507 - val_loss: 354.9063
# Epoch 19/100
# 125/125 [==============================] - 0s 934us/step - loss: 267.0309 - val_loss: 326.0822
# Epoch 20/100
# 125/125 [==============================] - 0s 959us/step - loss: 248.9205 - val_loss: 329.2579
# Epoch 21/100
# 125/125 [==============================] - 0s 938us/step - loss: 226.1492 - val_loss: 307.9017
# Epoch 22/100
# 125/125 [==============================] - 0s 930us/step - loss: 230.0841 - val_loss: 252.2497
# Epoch 23/100
# 125/125 [==============================] - 0s 949us/step - loss: 215.3220 - val_loss: 263.2263
# Epoch 24/100
# 125/125 [==============================] - 0s 939us/step - loss: 193.4219 - val_loss: 328.2148
# Epoch 25/100
# 125/125 [==============================] - 0s 951us/step - loss: 190.8324 - val_loss: 255.8108
# Epoch 26/100
# 125/125 [==============================] - 0s 927us/step - loss: 176.0626 - val_loss: 227.8052
# Epoch 27/100
# 125/125 [==============================] - 0s 934us/step - loss: 161.4244 - val_loss: 209.7867
# Epoch 28/100
# 125/125 [==============================] - 0s 946us/step - loss: 149.3524 - val_loss: 258.5084
# Epoch 29/100
# 125/125 [==============================] - 0s 940us/step - loss: 150.3059 - val_loss: 200.0247
# Epoch 30/100
# 125/125 [==============================] - 0s 935us/step - loss: 149.9555 - val_loss: 169.3541
# Epoch 31/100
# 125/125 [==============================] - 0s 933us/step - loss: 127.1660 - val_loss: 167.7086
# Epoch 32/100
# 125/125 [==============================] - 0s 954us/step - loss: 124.3074 - val_loss: 141.6626
# Epoch 33/100
# 125/125 [==============================] - 0s 920us/step - loss: 117.5695 - val_loss: 148.1661
# Epoch 34/100
# 125/125 [==============================] - 0s 914us/step - loss: 111.3323 - val_loss: 127.7957
# Epoch 35/100
# 125/125 [==============================] - 0s 941us/step - loss: 103.6454 - val_loss: 124.1572
# Epoch 36/100
# 125/125 [==============================] - 0s 918us/step - loss: 90.9486 - val_loss: 118.7003
# Epoch 37/100
# 125/125 [==============================] - 0s 928us/step - loss: 88.1825 - val_loss: 103.5180
# Epoch 38/100
# 125/125 [==============================] - 0s 932us/step - loss: 81.8141 - val_loss: 117.2926
# Epoch 39/100
# 125/125 [==============================] - 0s 936us/step - loss: 72.3962 - val_loss: 97.5918
# Epoch 40/100
# 125/125 [==============================] - 0s 928us/step - loss: 69.1458 - val_loss: 86.0990
# Epoch 41/100
# 125/125 [==============================] - 0s 932us/step - loss: 64.9738 - val_loss: 78.2293
# Epoch 42/100
# 125/125 [==============================] - 0s 914us/step - loss: 61.7698 - val_loss: 68.6907
# Epoch 43/100
# 125/125 [==============================] - 0s 936us/step - loss: 56.8475 - val_loss: 68.2491
# Epoch 44/100
# 125/125 [==============================] - 0s 931us/step - loss: 49.7388 - val_loss: 57.7044
# Epoch 45/100
# 125/125 [==============================] - 0s 932us/step - loss: 44.8905 - val_loss: 61.4652
# Epoch 46/100
# 125/125 [==============================] - 0s 915us/step - loss: 44.5479 - val_loss: 46.3351
# Epoch 47/100
# 125/125 [==============================] - 0s 925us/step - loss: 37.6113 - val_loss: 48.7271
# Epoch 48/100
# 125/125 [==============================] - 0s 919us/step - loss: 36.0300 - val_loss: 45.9482
# Epoch 49/100
# 125/125 [==============================] - 0s 940us/step - loss: 30.9523 - val_loss: 44.9750
# Epoch 50/100
# 125/125 [==============================] - 0s 929us/step - loss: 28.9278 - val_loss: 38.6161
# Epoch 51/100
# 125/125 [==============================] - 0s 949us/step - loss: 25.7068 - val_loss: 30.9189
# Epoch 52/100
# 125/125 [==============================] - 0s 969us/step - loss: 22.5380 - val_loss: 32.8329
# Epoch 53/100
# 125/125 [==============================] - 0s 976us/step - loss: 19.2403 - val_loss: 28.8627
# Epoch 54/100
# 125/125 [==============================] - 0s 957us/step - loss: 18.6102 - val_loss: 27.7939
# Epoch 55/100
# 125/125 [==============================] - 0s 947us/step - loss: 17.1381 - val_loss: 23.5391
# Epoch 56/100
# 125/125 [==============================] - 0s 972us/step - loss: 14.6563 - val_loss: 20.6668
# Epoch 57/100
# 125/125 [==============================] - 0s 964us/step - loss: 14.6824 - val_loss: 20.3527
# Epoch 58/100
# 125/125 [==============================] - 0s 952us/step - loss: 12.6846 - val_loss: 19.1923
# Epoch 59/100
# 125/125 [==============================] - 0s 938us/step - loss: 10.5831 - val_loss: 14.7945
# Epoch 60/100
# 125/125 [==============================] - 0s 906us/step - loss: 9.6391 - val_loss: 17.6161
# Epoch 61/100
# 125/125 [==============================] - 0s 1ms/step - loss: 11.3574 - val_loss: 15.3873
# Epoch 62/100
# 125/125 [==============================] - 0s 950us/step - loss: 9.1449 - val_loss: 15.2214
# Epoch 63/100
# 125/125 [==============================] - 0s 970us/step - loss: 7.5029 - val_loss: 12.7867
# Epoch 64/100
# 125/125 [==============================] - 0s 933us/step - loss: 6.4123 - val_loss: 12.1174
# Epoch 65/100
# 125/125 [==============================] - 0s 955us/step - loss: 6.3511 - val_loss: 22.3151
# Epoch 66/100
# 125/125 [==============================] - 0s 957us/step - loss: 6.4572 - val_loss: 14.8924
# Epoch 67/100
# 125/125 [==============================] - 0s 932us/step - loss: 4.3745 - val_loss: 9.2349
# Epoch 68/100
# 125/125 [==============================] - 0s 946us/step - loss: 5.1325 - val_loss: 10.8708
# Epoch 69/100
# 125/125 [==============================] - 0s 928us/step - loss: 4.4458 - val_loss: 9.7707
# Epoch 70/100
# 125/125 [==============================] - 0s 940us/step - loss: 4.0514 - val_loss: 10.1083
# Epoch 71/100
# 125/125 [==============================] - 0s 939us/step - loss: 3.9327 - val_loss: 9.7325
# Epoch 72/100
# 125/125 [==============================] - 0s 951us/step - loss: 3.5944 - val_loss: 8.7795
# Epoch 73/100
# 125/125 [==============================] - 0s 945us/step - loss: 3.2156 - val_loss: 9.3259
# Epoch 74/100
# 125/125 [==============================] - 0s 943us/step - loss: 3.3585 - val_loss: 8.0960
# Epoch 75/100
# 125/125 [==============================] - 0s 939us/step - loss: 2.5040 - val_loss: 8.3178
# Epoch 76/100
# 125/125 [==============================] - 0s 940us/step - loss: 2.2740 - val_loss: 7.9453
# Epoch 77/100
# 125/125 [==============================] - 0s 937us/step - loss: 2.1368 - val_loss: 7.8440
# Epoch 78/100
# 125/125 [==============================] - 0s 935us/step - loss: 2.5716 - val_loss: 6.7747
# Epoch 79/100
# 125/125 [==============================] - 0s 915us/step - loss: 2.6533 - val_loss: 5.5352
# Epoch 80/100
# 125/125 [==============================] - 0s 921us/step - loss: 2.0067 - val_loss: 5.4701
# Epoch 81/100
# 125/125 [==============================] - 0s 934us/step - loss: 2.3649 - val_loss: 8.0490
# Epoch 82/100
# 125/125 [==============================] - 0s 925us/step - loss: 1.7632 - val_loss: 9.3945
# Epoch 83/100
# 125/125 [==============================] - 0s 891us/step - loss: 1.6714 - val_loss: 9.0682
# Epoch 84/100
# 125/125 [==============================] - 0s 927us/step - loss: 1.4630 - val_loss: 8.1257
# Epoch 85/100
# 125/125 [==============================] - 0s 931us/step - loss: 1.4099 - val_loss: 9.0216
# Epoch 86/100
# 125/125 [==============================] - 0s 921us/step - loss: 1.3803 - val_loss: 9.1517
# Epoch 87/100
# 125/125 [==============================] - 0s 913us/step - loss: 1.5228 - val_loss: 7.6077
# Epoch 88/100
# 125/125 [==============================] - 0s 954us/step - loss: 1.1108 - val_loss: 7.1372
# Epoch 89/100
# 125/125 [==============================] - 0s 915us/step - loss: 1.3638 - val_loss: 7.1155
# Epoch 90/100
# 125/125 [==============================] - 0s 935us/step - loss: 1.3887 - val_loss: 7.2455
# Epoch 91/100
# 125/125 [==============================] - 0s 933us/step - loss: 1.2031 - val_loss: 6.7256
# Epoch 92/100
# 125/125 [==============================] - 0s 931us/step - loss: 0.8516 - val_loss: 6.7384
# Epoch 93/100
# 125/125 [==============================] - 0s 930us/step - loss: 1.1063 - val_loss: 5.6843
# Epoch 94/100
# 125/125 [==============================] - 0s 934us/step - loss: 1.1289 - val_loss: 5.4984
# Epoch 95/100
# 125/125 [==============================] - 0s 941us/step - loss: 0.5492 - val_loss: 5.3001
# Epoch 96/100
# 125/125 [==============================] - 0s 933us/step - loss: 0.8808 - val_loss: 5.3587
# Epoch 97/100
# 125/125 [==============================] - 0s 925us/step - loss: 1.1340 - val_loss: 5.2980
# Epoch 98/100
# 125/125 [==============================] - 0s 942us/step - loss: 1.4448 - val_loss: 5.0588
# Epoch 99/100
# 125/125 [==============================] - 0s 946us/step - loss: 1.1077 - val_loss: 4.8283
# Epoch 100/100
# 125/125 [==============================] - 0s 935us/step - loss: 1.2400 - val_loss: 4.9700
# Best epoch: 99

# %% [markdown]
# # **MAPIE**
#
# Load and wrap for `sklearn` compatibility (the wrapper assumes that the model is already trained):

# %%
class TrainedKerasRegressorWrapper(BaseEstimator, RegressorMixin):
    def __init__(self, model):
        self.model = model

    def fit(self, X, y):
        return self

    def predict(self, X):
        return self.model.predict(X).flatten()

    def __sklearn_is_fitted__(self):
        return True

model_files = ['modelP.keras', 'modelP.keras', 'modelP.keras']
wrapped_models = []

for file in model_files:
    loaded_model = load_model(file, compile=False)
    wrapped_model = TrainedKerasRegressorWrapper(loaded_model)
    wrapped_models.append(wrapped_model)

# %% [markdown]
# MAPIE quantile regression.
#
# The list of estimators consist of:
#
# * [0]: Estimator with quantile value of alpha/2
# * [1]: Estimator with quantile value of 1 - alpha/2
# * [2]: Estimator with quantile value of 0.5
# ```

# %%
mapie_regressor = MapieQuantileRegressor(
    estimator=wrapped_models, cv='prefit')

mapie_regressor.fit(X_cal, y_cal)

predictions, intervals = mapie_regressor.predict(X_test)

lower_intervals = intervals[:, 0]
upper_intervals = intervals[:, 1]

results = pd.DataFrame({
    'Prediction': predictions.flatten(),
    'Lower Interval': lower_intervals.flatten(),
    'Upper Interval': upper_intervals.flatten(),
    'Amplitude': upper_intervals.flatten() - lower_intervals.flatten(),
    'Actual Value': y_test
})

results.head()
# Out:
# 157/157 [==============================] - 0s 495us/step
# /home/antonio/code/uncertainty-pinns/.venv/lib/python3.10/site-packages/mapie/regression/quantile_regression.py:201: UserWarning: WARNING: The alpha that is set needs to be the same as the alpha of your prefitted model in the following order [alpha/2, 1 - alpha/2, 0.5]
#   warnings.warn(
# 157/157 [==============================] - 0s 472us/step
# 157/157 [==============================] - 0s 484us/step
# 157/157 [==============================] - 0s 484us/step
# 157/157 [==============================] - 0s 487us/step
# 157/157 [==============================] - 0s 475us/step
#      Prediction  Lower Interval  Upper Interval     Amplitude  Actual Value
# 0  4.822744e+05  -637313.437440    1.601862e+06  2.239176e+06      0.043215
# 1  1.071360e+06   -48227.968690    2.190948e+06  2.239176e+06      1.404347
# 2  1.586468e+05  -960941.031190    1.278235e+06  2.239176e+06     -0.640890
# 3  1.634895e+05  -956098.343690    1.283077e+06  2.239176e+06     -0.630405
# 4  1.482741e+05  -971313.734315    1.267862e+06  2.239176e+06     -0.670217
